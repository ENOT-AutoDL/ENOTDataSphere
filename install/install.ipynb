# %%
# install mmdet

# %%
# %pip install cython

# %%
# %pip install "git+https://github.com/open-mmlab/cocoapi.git#subdirectory=pycocotools"

# %%
# %pip install ./ENOTDataSphere/install/mmcv_full-latest+torch1.6.0+cu101-cp37-cp37m-manylinux1_x86_64.whl

# %%
#!L
# %pip install ./ENOTDataSphere/install/mmdet-2.3.0rc0+fb4007d-py3-none-any.whl

# %%
# %pip uninstall torch
# %pip uninstall torchvision

# %%
# %pip install torch==1.6.0 torchvision==0.7.0

# %%
# %pip install SharedArray
