# %%
#!L
import sys

sys.path.append('ENOTDataSphere')

from mmdet_tools.tools.train_baseline import train

# %%
#!L
config_path = '/home/jupyter/work/resources/ENOTDataSphere/mmdet_tools/configs/wider_face/mobilenet_ssd_mask.py'
work_dir = 'experiments/baseline_model'

# %%
#!L
train(config_path, work_dir)

# %%
#!L
